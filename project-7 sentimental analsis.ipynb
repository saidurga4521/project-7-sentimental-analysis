# %%
import pandas as pd

# %%
data=pd.read_table('C:\\Users\\saika\\Downloads\\train.csv.zip',
                  names=['id','title','author','text','label'])

# %%
data
# Out:
#                                                        id  title  author  \
# 0                              id,title,author,text,label    NaN     NaN
# 1       0,House Dem Aide: We Didn’t Even See Comey’s L...    NaN     NaN
# 2       With apologies to Keith Olbermann, there is no...    NaN     NaN
# 3       As we now know, Comey notified the Republican ...    NaN     NaN
# 4       — Jason Chaffetz (@jasoninthehouse) October 28...    NaN     NaN
# ...                                                   ...    ...     ...
# 141226  Wars are endangering the United States and oth...    NaN     NaN
# 141227                                   Add your name .     NaN     NaN
# 141228  David Swanson is an author, activist, journali...    NaN     NaN
# 141229  Follow him on Twitter: @davidcnswanson and Fac...    NaN     NaN
# 141230  Help support DavidSwanson.org, WarIsACrime.org...    NaN     NaN
#
#         text  label
# 0        NaN    NaN
# 1        NaN    NaN
# 2        NaN    NaN
# ...
